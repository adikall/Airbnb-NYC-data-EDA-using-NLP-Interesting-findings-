# %% [markdown]
# ### Import Data

# %%
import pandas as pd

# %% [markdown]
# #### Data Sets
#
# imported from - http://insideairbnb.com/get-the-data.html
#
# 1. 02 June, 2021 	New York City 	**listings.csv.gz** 	Detailed Listings data for New York City
# 2. 02 June, 2021 	New York City 	**calendar.csv.gz** 	Detailed Calendar Data for listings in New York City
# 3. 02 June, 2021 	New York City 	**reviews.csv.gz** 	    Detailed Review Data for listings in New York City
# 4. 02 June, 2021 	New York City 	**listings.csv** 	    Summary information and metrics for listings in New York City   (good for visualisations).
# 5. 02 June, 2021 	New York City 	**reviews.csv** 	    Summary Review data and Listing ID (to facilitate time based analytics and visualisations linked to a listing).

# %%
listings = pd.read_csv('listings.csv')
listings
# Out:
#              id                                               name    host_id  \
# 0          2595                              Skylit Midtown Castle       2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...       4869
# 2          5121                                    BlissArtsSpace!       7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden       7378
# 4          5178                   Large Furnished Room Near B'way　       8967
# ...         ...                                                ...        ...
# 36225  50164369  Fully Furnished Cozy Room in Upper West Side Home  305240193
# 36226  50165159    Fully Furnished Modern Room in West Harlem Home  305240193
# 36227  50165711  Furnished Sunlit Room in Lower East Side Apart...  305240193
# 36228  50165885  Classic Flatiron 2BR w/ W/D, Elevator, near Ea...  107434423
# 36229  50167934   Furnished Cozy Room in Upper West Side Apartment  305240193
#
#          host_name neighbourhood_group       neighbourhood   latitude  \
# 0         Jennifer           Manhattan             Midtown  40.753560
# 1      LisaRoxanne            Brooklyn  Bedford-Stuyvesant  40.684940
# 2            Garon            Brooklyn  Bedford-Stuyvesant  40.685350
# 3          Rebecca            Brooklyn         Sunset Park  40.662650
# 4         Shunichi           Manhattan             Midtown  40.764570
# ...            ...                 ...                 ...        ...
# 36225         June           Manhattan     Upper West Side  40.798766
# 36226         June           Manhattan              Harlem  40.811334
# 36227         June           Manhattan           Chinatown  40.715412
# 36228   Blueground           Manhattan   Flatiron District  40.743279
# 36229         June           Manhattan     Upper West Side  40.799863
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0     -73.985590  Entire home/apt    150              30                 48
# 1     -73.957650  Entire home/apt     79               1                403
# 2     -73.955120     Private room     60              30                 50
# 3     -73.994540  Entire home/apt    175              21                  1
# 4     -73.983170     Private room     61               2                474
# ...          ...              ...    ...             ...                ...
# 36225 -73.964027     Private room     76              30                  0
# 36226 -73.954073     Private room     58              30                  0
# 36227 -73.992864     Private room     74              30                  0
# 36228 -73.991203  Entire home/apt    281              30                  0
# 36229 -73.961523     Private room     79              30                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2019-11-04               0.34                               3
# 1      2021-05-04               5.16                               1
# 2      2016-06-05               0.56                               1
# 3      2014-01-02               0.01                               1
# 4      2020-09-25               3.61                               1
# ...           ...                ...                             ...
# 36225         NaN                NaN                             283
# 36226         NaN                NaN                             283
# 36227         NaN                NaN                             283
# 36228         NaN                NaN                             278
# 36229         NaN                NaN                             283
#
#        availability_365
# 0                   308
# 1                   208
# 2                   365
# 3                   134
# 4                   246
# ...                 ...
# 36225                 1
# 36226               307
# 36227               304
# 36228               299
# 36229               303
#
# [36230 rows x 16 columns]

# %%
listings_d = pd.read_csv('listings_d.csv')
listings_d
# Out:
#              id                            listing_url       scrape_id  \
# 0          2595      https://www.airbnb.com/rooms/2595  20210602135139
# 1          3831      https://www.airbnb.com/rooms/3831  20210602135139
# 2          5121      https://www.airbnb.com/rooms/5121  20210602135139
# 3          5136      https://www.airbnb.com/rooms/5136  20210602135139
# 4          5178      https://www.airbnb.com/rooms/5178  20210602135139
# ...         ...                                    ...             ...
# 36225  50164369  https://www.airbnb.com/rooms/50164369  20210602135139
# 36226  50165159  https://www.airbnb.com/rooms/50165159  20210602135139
# 36227  50165711  https://www.airbnb.com/rooms/50165711  20210602135139
# 36228  50165885  https://www.airbnb.com/rooms/50165885  20210602135139
# 36229  50167934  https://www.airbnb.com/rooms/50167934  20210602135139
#
#       last_scraped                                               name  \
# 0       2021-06-05                              Skylit Midtown Castle
# 1       2021-06-06  Whole flr w/private bdrm, bath & kitchen(pls r...
# 2       2021-06-05                                    BlissArtsSpace!
# 3       2021-06-04           Spacious Brooklyn Duplex, Patio + Garden
# 4       2021-06-04                   Large Furnished Room Near B'way
# ...            ...                                                ...
# 36225   2021-06-05  Fully Furnished Cozy Room in Upper West Side Home
# 36226   2021-06-04    Fully Furnished Modern Room in West Harlem Home
# 36227   2021-06-04  Furnished Sunlit Room in Lower East Side Apart...
# 36228   2021-06-03  Classic Flatiron 2BR w/ W/D, Elevator, near Ea...
# 36229   2021-06-04   Furnished Cozy Room in Upper West Side Apartment
#
#                                              description  \
# 0      Beautiful, spacious skylit studio in the heart...
# 1      Enjoy 500 s.f. top floor in 1899 brownstone, w...
# 2      <b>The space</b><br />HELLO EVERYONE AND THANK...
# 3      We welcome you to stay in our lovely 2 br dupl...
# 4      Please don’t expect the luxury here just a bas...
# ...                                                  ...
# 36225  Full room in a 3-bedroom, 2-bathroom shared ho...
# 36226  Queen room in a 4-bedroom, 1-bathroom shared h...
# 36227  Queen room in a 3-bedroom, 1-bathroom shared h...
# 36228  Feel at home wherever you choose to live with ...
# 36229  Queen room in a 3-bedroom, 2-bathroom shared h...
#
#                                    neighborhood_overview  \
# 0      Centrally located in the heart of Manhattan ju...
# 1      Just the right mix of urban center and local n...
# 2                                                    NaN
# 3                                                    NaN
# 4        Theater district, many restaurants around here.
# ...                                                  ...
# 36225                                                NaN
# 36226                                                NaN
# 36227                                                NaN
# 36228  This furnished apartment is located in Chelsea...
# 36229                                                NaN
#
#                                              picture_url    host_id  \
# 0      https://a0.muscache.com/pictures/f0813a11-40b2...       2845
# 1      https://a0.muscache.com/pictures/e49999c2-9fd5...       4869
# 2      https://a0.muscache.com/pictures/2090980c-b68e...       7356
# 3      https://a0.muscache.com/pictures/a3f7ace8-e7a9...       7378
# 4      https://a0.muscache.com/pictures/12065/f070997...       8967
# ...                                                  ...        ...
# 36225  https://a0.muscache.com/pictures/2e3a2a1c-d47a...  305240193
# 36226  https://a0.muscache.com/pictures/379a1703-be3c...  305240193
# 36227  https://a0.muscache.com/pictures/0aae591f-a364...  305240193
# 36228  https://a0.muscache.com/pictures/prohost-api/H...  107434423
# 36229  https://a0.muscache.com/pictures/1649e8b7-be1a...  305240193
#
#                                           host_url  ...  \
# 0           https://www.airbnb.com/users/show/2845  ...
# 1           https://www.airbnb.com/users/show/4869  ...
# 2           https://www.airbnb.com/users/show/7356  ...
# 3           https://www.airbnb.com/users/show/7378  ...
# 4           https://www.airbnb.com/users/show/8967  ...
# ...                                            ...  ...
# 36225  https://www.airbnb.com/users/show/305240193  ...
# 36226  https://www.airbnb.com/users/show/305240193  ...
# 36227  https://www.airbnb.com/users/show/305240193  ...
# 36228  https://www.airbnb.com/users/show/107434423  ...
# 36229  https://www.airbnb.com/users/show/305240193  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                            4.79                   4.86                4.41
# 1                            4.80                   4.72                4.64
# 2                            4.91                   4.47                4.52
# 3                            5.00                   4.00                5.00
# 4                            4.39                   4.86                4.34
# ...                           ...                    ...                 ...
# 36225                         NaN                    NaN                 NaN
# 36226                         NaN                    NaN                 NaN
# 36227                         NaN                    NaN                 NaN
# 36228                         NaN                    NaN                 NaN
# 36229                         NaN                    NaN                 NaN
#
#       license instant_bookable calculated_host_listings_count  \
# 0         NaN                f                              3
# 1         NaN                f                              1
# 2         NaN                f                              1
# 3         NaN                f                              1
# 4         NaN                f                              1
# ...       ...              ...                            ...
# 36225     NaN                f                            283
# 36226     NaN                f                            283
# 36227     NaN                f                            283
# 36228     NaN                t                            278
# 36229     NaN                f                            283
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               3
# 1                                               1
# 2                                               0
# 3                                               1
# 4                                               0
# ...                                           ...
# 36225                                          45
# 36226                                          45
# 36227                                          45
# 36228                                         278
# 36229                                          45
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                1
# 3                                                0
# 4                                                1
# ...                                            ...
# 36225                                          238
# 36226                                          238
# 36227                                          238
# 36228                                            0
# 36229                                          238
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              0.34
# 1                                               0              5.16
# 2                                               0              0.56
# 3                                               0              0.01
# 4                                               0              3.61
# ...                                           ...               ...
# 36225                                           0               NaN
# 36226                                           0               NaN
# 36227                                           0               NaN
# 36228                                           0               NaN
# 36229                                           0               NaN
#
# [36230 rows x 74 columns]

# %%
for i in listings_d.columns:
    print(i)
# Out:
# id
# listing_url
# scrape_id
# last_scraped
# name
# description
# neighborhood_overview
# picture_url
# host_id
# host_url
# host_name
# host_since
# host_location
# host_about
# host_response_time
# host_response_rate
# host_acceptance_rate
# host_is_superhost
# host_thumbnail_url
# host_picture_url
# host_neighbourhood
# host_listings_count
# host_total_listings_count
# host_verifications
# host_has_profile_pic
# host_identity_verified
# neighbourhood
# neighbourhood_cleansed
# neighbourhood_group_cleansed
# latitude
# longitude
# property_type
# room_type
# accommodates
# bathrooms
# bathrooms_text
# bedrooms
# beds
# amenities
# price
# minimum_nights
# maximum_nights
# minimum_minimum_nights
# maximum_minimum_nights
# minimum_maximum_nights
# maximum_maximum_nights
# minimum_nights_avg_ntm
# maximum_nights_avg_ntm
# calendar_updated
# has_availability
# availability_30
# availability_60
# availability_90
# availability_365
# calendar_last_scraped
# number_of_reviews
# number_of_reviews_ltm
# number_of_reviews_l30d
# first_review
# last_review
# review_scores_rating
# review_scores_accuracy
# review_scores_cleanliness
# review_scores_checkin
# review_scores_communication
# review_scores_location
# review_scores_value
# license
# instant_bookable
# calculated_host_listings_count
# calculated_host_listings_count_entire_homes
# calculated_host_listings_count_private_rooms
# calculated_host_listings_count_shared_rooms
# reviews_per_month

# %%
reviews = pd.read_csv('reviews.csv')
reviews
# Out:
#         listing_id        date
# 0             2595  2009-11-21
# 1             2595  2009-12-05
# 2             2595  2009-12-10
# 3             2595  2010-04-09
# 4             2595  2010-05-25
# ...            ...         ...
# 821853    50038208  2021-05-31
# 821854    50038458  2021-05-29
# 821855    50051908  2021-05-31
# 821856    50073673  2021-05-31
# 821857    50073875  2021-05-31
#
# [821858 rows x 2 columns]

# %%
reviews_d = pd.read_csv('reviews_d.csv')

reviews_d
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0        2595     17857  2009-11-21        50679          Jean
# 1        2595     19176  2009-12-05        53267          Cate
# 2        2595     19760  2009-12-10        38960         Anita
# 3        2595     34320  2010-04-09        71130       Kai-Uwe
# 4        2595     46312  2010-05-25       117113        Alicia
# 5        2595   1238204  2012-05-07      1783688        Sergey
# 6        2595   1293632  2012-05-17      1870771          Loïc
# 7        2595   2022498  2012-08-18      2124102       Melanie
# 8        2595   4682989  2013-05-20       496053          Eric
# 9        2595  13193832  2014-05-21     13685934        Gerald
#
#                                             comments
# 0  Notre séjour de trois nuits.\r\nNous avons app...
# 1                                  Great experience.
# 2  I've stayed with my friend at the Midtown Cast...
# 3  We've been staying here for about 9 nights, en...
# 4  We had a wonderful stay at Jennifer's charming...
# 5  Hi to everyone!\r\nWould say our greatest comp...
# 6  Jennifer was very friendly and helpful, and he...
# 7  This apartment is like a real castle old and u...
# 8  Jennifer's place was in a great midtown locati...
# 9  Jennifer is a very nice host. Everything is cl...

# %% [markdown]
# ### To-do

# %% [markdown]
# - Basic Analysis on the Data Sets
#
# - Use NLP techniques on Airbnb listing, reviews, etc.
# - topic modeling
# - sentiment analysis
# - what else could you do?
#
# - pytorch
# - Nvidia GPU
#
# - Understand why to do all of this, why would the text give you new results over the traditional analysis is there something similar, how will this information help the listing owners ?

# %% [markdown]
# ## What are the kinds of things people talk about in the reviews. Is there anything common

# %%
reviews_d.comments
# Out:
# 0    Notre séjour de trois nuits.\r\nNous avons app...
# 1                                    Great experience.
# 2    I've stayed with my friend at the Midtown Cast...
# 3    We've been staying here for about 9 nights, en...
# 4    We had a wonderful stay at Jennifer's charming...
# 5    Hi to everyone!\r\nWould say our greatest comp...
# 6    Jennifer was very friendly and helpful, and he...
# 7    This apartment is like a real castle old and u...
# 8    Jennifer's place was in a great midtown locati...
# 9    Jennifer is a very nice host. Everything is cl...
# Name: comments, dtype: object

# %% [markdown]
# ## Per listing what is the overall sentiment of the reviews - put this into a metric
#
# - find nlp analysis that was done on kaggle
#
#
# - can we find something to improve

# %%
# Python program to generate WordCloud

# importing all necessary modules
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd


comment_words = ''
stopwords = set(STOPWORDS)

# iterate through the csv file
for val in reviews_d.comments:

# typecaste each val to string
    val = str(val)

# split the value
    tokens = val.split()

# Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
        comment_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)

# plot the WordCloud image 
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()
